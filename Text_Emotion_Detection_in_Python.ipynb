# %%
! pip install transformers -q
# Out:
#      |████████████████████████████████| 3.4 MB 14.8 MB/s
#      |████████████████████████████████| 3.3 MB 32.8 MB/s
#      |████████████████████████████████| 61 kB 519 kB/s
#      |████████████████████████████████| 596 kB 68.4 MB/s
#      |████████████████████████████████| 895 kB 75.3 MB/s

# %%
from transformers import pipeline

# %%
# tokenizer = RobertaTokenizerFast.from_pretrained("arpanghoshal/EmoRoBERTa")
# model = TFRobertaForSequenceClassification.from_pretrained("arpanghoshal/EmoRoBERTa")

# %% [markdown]
# # id 	label
#
# ```
# 0 	anger
# 1 	cheeky
# 2 	confuse
# 3 	curious
# 4 	disgust
# 5 	empathetic
# 6 	energetic
# 7 	fear
# 8 	grumpy
# 9 	guilty
# 10 	impatient
# 11 	joy
# 12 	love
# 13 	neutral
# 14 	sadness
# 15 	serious
# 16 	surprise
# 17 	suspicious
# 18 	think
# 19 	whiny
# ```

# %%
from transformers import AutoModelForSequenceClassification, pipeline


model_name = 'jitesh/emotion-english'
model = AutoModelForSequenceClassification.from_pretrained(model_name)
classifier = pipeline("text-classification", model=model, tokenizer=model_name)

text = "I can't wait any longer "

prediction = classifier(text)
print(prediction[0], text)
# Out:
# Downloading (…)lve/main/config.json: 100%|██████████| 1.58k/1.58k [00:00<00:00, 439kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 329M/329M [01:50<00:00, 2.96MB/s]
# Downloading (…)okenizer_config.json: 100%|██████████| 346/346 [00:00<00:00, 173kB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 798k/798k [00:00<00:00, 11.5MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 30.2MB/s]
# Downloading (…)/main/tokenizer.json: 100%|██████████| 2.11M/2.11M [00:00<00:00, 18.8MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 280/280 [00:00<00:00, 93.4kB/s]
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# {'label': 'impatient', 'score': 0.9242119789123535} I can't wait any longer
